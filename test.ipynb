# %%
import torch
from utils import Visualizer
import matplotlib.pyplot as plt
from utils import  BreastCancerDataset
from preprocess import get_preprocessor
img_path = '../archive/patient1.pt'
img =torch.load(img_path)

v = Visualizer()

# %%
prep = get_preprocessor()
raw_img = prep.get_raw_data(0)[0]
# Out:
# sliced folder exists
# ./data\patients\patient1.nii.gz
# ./data\masks\segmentation1.nrrd

# %%
v.visualize_distribution(raw_img)
# Out:
# mean: metatensor(59.6925)
# std: metatensor(68.9349)

# %%
img_path = f'../archive/patient{i}.pt'
old_img =torch.load(img_path)[0]
v.visualize_distribution(old_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 img_path = f'../archive/patient{i}.pt'
#       2 old_img =torch.load(img_path)[0]
#       3 v.visualize_distribution(old_img)
#
# NameError: name 'i' is not defined

# %%
img_path = f'sliced/sliced__256_64_float32/patient{i}.pt'
new_img =torch.load(img_path)['image']
v.visualize_distribution(new_img)
# Out:
# mean: tensor(0.0779)
# std: tensor(0.0726)

# %%
plt.imshow(raw_img[:,:,10])

# %%
plt.imshow(old_img[:,:,10])

# %%
plt.imshow(new_img[:,:,10])

# %%
img.shape
# Out:
# torch.Size([2, 64, 128, 128])
